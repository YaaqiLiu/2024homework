# %%
# 导入数据
import pandas as pd
text_ana = pd.read_csv('E:\\研一作业\\text_analysis_twitter.csv')
text_ana = text_ana.drop(['Unnamed: 0'], axis=1)

# %%
import re

def preprocess_text(text):    
    # 转换为小写
    text = text.lower()   
    # 移除URL
    text = re.sub(r'http\S+', '', text)    
    return text

# %%
from sklearn.feature_extraction.text import CountVectorizer

# 初始化CountVectorizer
vectorizer = CountVectorizer()

# 将文本数据转换为词袋特征矩阵
X = vectorizer.fit_transform(text_ana["text"].apply(preprocess_text))

# 展示特征矩阵的形状
print('词袋特征矩阵的形状:', X.shape)

# 展示词袋模型中的所有特征词
print('特征词列表:', vectorizer.get_feature_names_out())
# Out:
# 词袋特征矩阵的形状: (300000, 121376)
# 特征词列表: ['00' '000' '0000' ... '투표하십시오' '한국어' 'ﬂees']

# %%
list(X.toarray())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 4
#       2 # 使用稀疏矩阵
#       3 X_sparse = csr_matrix(X)
# ----> 4 list(X.toarray())
#
# File D:\anacondatry\Lib\site-packages\scipy\sparse\_compressed.py:1050, in _cs_matrix.toarray(self, order, out)
#    1048 if out is None and order is None:
#    1049     order = self._swap('cf')[0]
# -> 1050 out = self._process_toarray_args(order, out)
#    1051 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1052     raise ValueError('Output array must be C or F contiguous')
#
# File D:\anacondatry\Lib\site-packages\scipy\sparse\_base.py:1267, in _spbase._process_toarray_args(self, order, out)
#    1265     return out
#    1266 else:
# -> 1267     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 271. GiB for an array with shape (300000, 121376) and data type int64

# %%
# 获取词汇表
feature_words = vectorizer.get_feature_names_out()

# 计算词频统计
word_freq = dict(zip(feature_words, X.sum(axis=0).A1))

# %%
# 观察词袋模型的词频计数结果
sorted (word_freq.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('the', 247160),
#  ('to', 235370),
#  ('of', 112428),
#  ('in', 104912),
#  ('and', 104025),
#  ('for', 102100),
#  ('rt', 83461),
#  ('on', 72986),
#  ('amp', 65500),
#  ('is', 64785),
#  ('we', 53564),
#  ('our', 49736),
#  ('this', 45532),
#  ('you', 40235),
#  ('with', 39027),
#  ('it', 38749),
#  ('that', 38161),
#  ('qt', 35691),
#  ('at', 33821),
#  ('are', 31301),
#  ('will', 29565),
#  ('tax', 28529),
#  ('my', 27644),
#  ('be', 26920),
#  ('from', 26202),
#  ('today', 24574),
#  ('have', 23005),
#  ('by', 22865),
#  ('more', 22665),
#  ('trump', 19894),
#  ('bill', 19534),
#  ('their', 19129),
#  ('about', 18973),
#  ('as', 18391),
#  ('all', 18295),
#  ('not', 18197),
#  ('your', 17615),
#  ('who', 17098),
#  ('can', 15465),
#  ('health', 14215),
#  ('has', 14119),
#  ('an', 13861),
#  ('they', 13858),
#  ('us', 13825),
#  ('here', 13799),
#  ('house', 13680),
#  ('people', 13486),
#  ('great', 13468),
#  ('now', 13113),
#  ('families', 12838),
#  ('must', 12787),
#  ('up', 12602),
#  ('was', 12513),
#  ('need', 12313),
#  ('americans', 12279),
#  ('help', 12145),
#  ('act', 12064),
#  ('out', 12041),
#  ('care', 11783),
#  ('thank', 11563),
#  ('no', 11363),
#  ('if', 11323),
#  ('time', 11174),
#  ('what', 11144),
#  ('new', 11048),
#  ('senate', 10880),
#  ('his', 10843),
#  ('congress', 10651),
#  ('work', 10314),
#  ('would', 10271),
#  ('gop', 10245),
#  ('american', 10072),
#  ('just', 9983),
#  ('support', 9669),
#  ('he', 9539),
#  ('how', 9424),
#  ('but', 9394),
#  ('do', 9376),
#  ('so', 9331),
#  ('plan', 9101),
#  ('should', 9068),
#  ('day', 8892),
#  ('get', 8849),
#  ('re', 8699),
#  ('realdonaldtrump', 8614),
#  ('vote', 8505),
#  ('one', 8503),
#  ('make', 8333),
#  ('or', 8312),
#  ('taxreform', 8048),
#  ('working', 7953),
#  ('president', 7872),
#  ('jobs', 7859),
#  ('potus', 7850),
#  ('thanks', 7636),
#  ('see', 7585),
#  ('me', 7508),
#  ('reform', 7450),
#  ('live', 7327),
#  ('country', 7229),
#  ('proud', 7140),
#  ('watch', 7115),
#  ('america', 7022),
#  ('those', 6769),
#  ('than', 6597),
#  ('like', 6590),
#  ('middle', 6555),
#  ('them', 6547),
#  ('back', 6539),
#  ('state', 6475),
#  ('cuts', 6444),
#  ('first', 6431),
#  ('read', 6418),
#  ('women', 6343),
#  ('let', 6199),
#  ('join', 6177),
#  ('class', 6176),
#  ('over', 6176),
#  ('year', 6110),
#  ('there', 6105),
#  ('been', 6084),
#  ('when', 5996),
#  ('week', 5973),
#  ('keep', 5944),
#  ('veterans', 5932),
#  ('against', 5803),
#  ('why', 5753),
#  ('good', 5752),
#  ('family', 5735),
#  ('don', 5669),
#  ('happy', 5662),
#  ('protect', 5642),
#  ('republicans', 5635),
#  ('right', 5602),
#  ('these', 5600),
#  ('bipartisan', 5514),
#  ('last', 5490),
#  ('after', 5488),
#  ('take', 5481),
#  ('national', 5414),
#  ('many', 5381),
#  ('know', 5322),
#  ('fight', 5238),
#  ('every', 5187),
#  ('years', 5151),
#  ('community', 5119),
#  ('hearing', 5078),
#  ('nation', 4940),
#  ('taxes', 4763),
#  ('passed', 4748),
#  ('economy', 4734),
#  ('rep', 4716),
#  ('service', 4682),
#  ('pass', 4671),
#  ('want', 4669),
#  ('stand', 4661),
#  ('news', 4630),
#  ('discuss', 4617),
#  ('stop', 4605),
#  ('goptaxscam', 4589),
#  ('ll', 4541),
#  ('statement', 4528),
#  ('10', 4506),
#  ('dreamers', 4488),
#  ('healthcare', 4479),
#  ('morning', 4445),
#  ('via', 4396),
#  ('call', 4377),
#  ('law', 4365),
#  ('important', 4359),
#  ('daca', 4322),
#  ('million', 4308),
#  ('gt', 4268),
#  ('into', 4264),
#  ('ve', 4254),
#  ('federal', 4251),
#  ('am', 4223),
#  ('go', 4209),
#  ('way', 4179),
#  ('continue', 4171),
#  ('only', 4165),
#  ('open', 4142),
#  ('security', 4127),
#  ('says', 4126),
#  ('office', 4079),
#  ('next', 4011),
#  ('still', 3994),
#  ('000', 3984),
#  ('its', 3982),
#  ('students', 3975),
#  ('members', 3967),
#  ('committee', 3958),
#  ('public', 3954),
#  ('better', 3933),
#  ('amendment', 3888),
#  ('military', 3888),
#  ('meeting', 3879),
#  ('honor', 3849),
#  ('which', 3847),
#  ('under', 3846),
#  ('local', 3827),
#  ('cut', 3801),
#  ('full', 3798),
#  ('tune', 3771),
#  ('before', 3756),
#  ('county', 3751),
#  ('down', 3748),
#  ('pay', 3714),
#  ('had', 3710),
#  ('lives', 3678),
#  ('big', 3665),
#  ('her', 3663),
#  ('being', 3631),
#  ('tonight', 3630),
#  ('white', 3628),
#  ('repeal', 3624),
#  ('together', 3615),
#  ('end', 3608),
#  ('most', 3589),
#  ('budget', 3569),
#  ('relief', 3569),
#  ('home', 3533),
#  ('legislation', 3531),
#  ('across', 3505),
#  ('give', 3504),
#  ('forward', 3501),
#  ('some', 3497),
#  ('breaking', 3490),
#  ('millions', 3470),
#  ('communities', 3467),
#  ('could', 3447),
#  ('children', 3327),
#  ('access', 3325),
#  ('visit', 3325),
#  ('were', 3313),
#  ('other', 3307),
#  ('everyone', 3292),
#  ('hard', 3284),
#  ('insurance', 3282),
#  ('funding', 3278),
#  ('republican', 3273),
#  ('talk', 3272),
#  ('world', 3261),
#  ('going', 3258),
#  ('aca', 3253),
#  ('through', 3243),
#  ('off', 3223),
#  ('tomorrow', 3216),
#  ('states', 3214),
#  ('future', 3200),
#  ('businesses', 3194),
#  ('trumpcare', 3188),
#  ('learn', 3181),
#  ('please', 3100),
#  ('business', 3098),
#  ('safe', 3090),
#  ('again', 3069),
#  ('fighting', 3069),
#  ('needs', 3059),
#  ('small', 3059),
#  ('during', 3058),
#  ('program', 3057),
#  ('efforts', 3039),
#  ('code', 3038),
#  ('colleagues', 3036),
#  ('much', 3034),
#  ('housegop', 3006),
#  ('because', 2996),
#  ('deserve', 2994),
#  ('him', 2994),
#  ('any', 2984),
#  ('victims', 2963),
#  ('north', 2951),
#  ('made', 2921),
#  ('puerto', 2907),
#  ('while', 2897),
#  ('best', 2891),
#  ('icymi', 2887),
#  ('floor', 2884),
#  ('very', 2879),
#  ('joined', 2878),
#  ('too', 2878),
#  ('leadership', 2877),
#  ('leaders', 2876),
#  ('life', 2875),
#  ('system', 2875),
#  ('making', 2871),
#  ('yesterday', 2871),
#  ('another', 2856),
#  ('job', 2840),
#  ('administration', 2820),
#  ('obamacare', 2817),
#  ('rights', 2798),
#  ('violence', 2787),
#  ('action', 2786),
#  ('democrats', 2786),
#  ('even', 2781),
#  ('never', 2780),
#  ('say', 2770),
#  ('harvey', 2760),
#  ('medicaid', 2702),
#  ('also', 2698),
#  ('come', 2686),
#  ('put', 2668),
#  ('school', 2660),
#  ('russia', 2659),
#  ('night', 2658),
#  ('step', 2623),
#  ('rico', 2615),
#  ('look', 2599),
#  ('change', 2595),
#  ('sure', 2549),
#  ('long', 2540),
#  ('won', 2528),
#  ('coverage', 2520),
#  ('ensure', 2520),
#  ('2017', 2519),
#  ('money', 2517),
#  ('check', 2513),
#  ('texas', 2501),
#  ('birthday', 2500),
#  ('does', 2494),
#  ('find', 2480),
#  ('government', 2472),
#  ('workers', 2472),
#  ('hope', 2466),
#  ('washington', 2462),
#  ('debate', 2460),
#  ('gun', 2458),
#  ('special', 2458),
#  ('hurricane', 2442),
#  ('congressional', 2436),
#  ('high', 2417),
#  ('raise', 2392),
#  ('agree', 2389),
#  ('economic', 2380),
#  ('prayers', 2377),
#  ('crisis', 2369),
#  ('since', 2363),
#  ('free', 2361),
#  ('meet', 2360),
#  ('town', 2358),
#  ('said', 2347),
#  ('done', 2346),
#  ('staff', 2338),
#  ('always', 2329),
#  ('provide', 2329),
#  ('de', 2327),
#  ('medicare', 2325),
#  ('did', 2322),
#  ('real', 2321),
#  ('power', 2316),
#  ('speakerryan', 2309),
#  ('policy', 2293),
#  ('away', 2292),
#  ('where', 2277),
#  ('attack', 2274),
#  ('growth', 2274),
#  ('education', 2267),
#  ('corporations', 2248),
#  ('increase', 2232),
#  ('hall', 2226),
#  ('thoughts', 2204),
#  ('center', 2202),
#  ('top', 2198),
#  ('may', 2194),
#  ('opportunity', 2189),
#  ('11', 2188),
#  ('without', 2188),
#  ('part', 2185),
#  ('hear', 2180),
#  ('issues', 2180),
#  ('voted', 2179),
#  ('city', 2173),
#  ('well', 2171),
#  ('glad', 2170),
#  ('friends', 2168),
#  ('honored', 2168),
#  ('united', 2167),
#  ('update', 2163),
#  ('chairman', 2154),
#  ('joining', 2154),
#  ('senator', 2148),
#  ('district', 2145),
#  ('report', 2136),
#  ('sen', 2134),
#  ('until', 2134),
#  ('senategop', 2130),
#  ('looking', 2129),
#  ('talking', 2114),
#  ('bring', 2111),
#  ('30', 2110),
#  ('critical', 2105),
#  ('energy', 2097),
#  ('latest', 2090),
#  ('letter', 2085),
#  ('voting', 2085),
#  ('lost', 2083),
#  ('water', 2079),
#  ('info', 2067),
#  ('story', 2066),
#  ('co', 2063),
#  ('korea', 2062),
#  ('affordable', 2053),
#  ('young', 2052),
#  ('doesn', 2047),
#  ('serve', 2046),
#  ('decision', 2043),
#  ('speaking', 2040),
#  ('remember', 2035),
#  ('taking', 2034),
#  ('history', 2033),
#  ('create', 2031),
#  ('men', 2026),
#  ('dreamact', 2025),
#  ('two', 2023),
#  ('dc', 2017),
#  ('place', 2014),
#  ('she', 2010),
#  ('kids', 2000),
#  ('fire', 1996),
#  ('justice', 1993),
#  ('opioid', 1989),
#  ('including', 1981),
#  ('va', 1981),
#  ('coming', 1962),
#  ('ready', 1962),
#  ('disaster', 1955),
#  ('safety', 1953),
#  ('speak', 1953),
#  ('strong', 1949),
#  ('15', 1948),
#  ('questions', 1942),
#  ('use', 1941),
#  ('sign', 1940),
#  ('think', 1940),
#  ('clear', 1928),
#  ('team', 1928),
#  ('improve', 1920),
#  ('fair', 1904),
#  ('stay', 1903),
#  ('ago', 1901),
#  ('puertorico', 1901),
#  ('friend', 1898),
#  ('helping', 1896),
#  ('around', 1891),
#  ('own', 1891),
#  ('climate', 1885),
#  ('income', 1877),
#  ('bad', 1876),
#  ('doing', 1874),
#  ('recovery', 1866),
#  ('deal', 1864),
#  ('congrats', 1861),
#  ('show', 1860),
#  ('2018', 1850),
#  ('days', 1845),
#  ('met', 1837),
#  ('war', 1833),
#  ('getting', 1825),
#  ('12', 1823),
#  ('billion', 1808),
#  ('congressman', 1801),
#  ('benefits', 1799),
#  ('costs', 1782),
#  ('resources', 1772),
#  ('debt', 1770),
#  ('both', 1769),
#  ('member', 1768),
#  ('ever', 1763),
#  ('win', 1744),
#  ('congratulations', 1738),
#  ('clean', 1735),
#  ('wealthy', 1734),
#  ('immigration', 1732),
#  ('foxnews', 1729),
#  ('bills', 1726),
#  ('isn', 1723),
#  ('repjayapal', 1714),
#  ('cannot', 1711),
#  ('20', 1708),
#  ('conference', 1706),
#  ('means', 1702),
#  ('same', 1695),
#  ('calling', 1693),
#  ('thehill', 1689),
#  ('getcovered', 1686),
#  ('las', 1683),
#  ('enrollment', 1682),
#  ('makes', 1672),
#  ('cost', 1665),
#  ('fema', 1663),
#  ('love', 1663),
#  ('event', 1657),
#  ('introduced', 1657),
#  ('election', 1654),
#  ('information', 1654),
#  ('celebrate', 1651),
#  ('address', 1648),
#  ('share', 1647),
#  ('premiums', 1646),
#  ('save', 1643),
#  ('emergency', 1639),
#  ('force', 1635),
#  ('got', 1635),
#  ('irma', 1631),
#  ('less', 1628),
#  ('ed', 1627),
#  ('voice', 1625),
#  ('welcome', 1623),
#  ('few', 1615),
#  ('charlottesville', 1614),
#  ('protectdreamers', 1614),
#  ('campaign', 1604),
#  ('response', 1604),
#  ('tell', 1604),
#  ('lose', 1603),
#  ('rule', 1603),
#  ('supporting', 1601),
#  ('political', 1600),
#  ('having', 1599),
#  ('programs', 1599),
#  ('grateful', 1585),
#  ('dems', 1573),
#  ('yet', 1572),
#  ('sexual', 1562),
#  ('process', 1560),
#  ('grahamcassidy', 1559),
#  ('hold', 1551),
#  ('epa', 1550),
#  ('lead', 1550),
#  ('month', 1549),
#  ('admin', 1541),
#  ('discussion', 1541),
#  ('order', 1540),
#  ('assistance', 1536),
#  ('allow', 1534),
#  ('spoke', 1527),
#  ('press', 1523),
#  ('seniors', 1522),
#  ('responders', 1521),
#  ('john', 1519),
#  ('start', 1516),
#  ('effort', 1514),
#  ('vegas', 1514),
#  ('la', 1513),
#  ('nearly', 1510),
#  ('medical', 1508),
#  ('risk', 1508),
#  ('internet', 1507),
#  ('believe', 1501),
#  ('able', 1500),
#  ('protectourcare', 1500),
#  ('soon', 1499),
#  ('wrong', 1496),
#  ('pro', 1493),
#  ('enough', 1486),
#  ('child', 1482),
#  ('deduction', 1481),
#  ('pm', 1481),
#  ('move', 1480),
#  ('issue', 1478),
#  ('obama', 1478),
#  ('air', 1477),
#  ('officials', 1467),
#  ('hate', 1462),
#  ('enjoyed', 1461),
#  ('senators', 1454),
#  ('former', 1450),
#  ('infrastructure', 1449),
#  ('listen', 1447),
#  ('capitol', 1446),
#  ('standing', 1445),
#  ('iran', 1444),
#  ('anti', 1443),
#  ('rich', 1434),
#  ('defense', 1428),
#  ('nothing', 1428),
#  ('netneutrality', 1427),
#  ('services', 1425),
#  ('chip', 1422),
#  ('credit', 1420),
#  ('cnn', 1417),
#  ('happening', 1417),
#  ('transgender', 1417),
#  ('protecting', 1414),
#  ('secretary', 1414),
#  ('between', 1412),
#  ('human', 1412),
#  ('food', 1405),
#  ('freedom', 1404),
#  ('line', 1399),
#  ('trying', 1398),
#  ('fix', 1392),
#  ('rural', 1390),
#  ('hardworking', 1389),
#  ('higher', 1389),
#  ('lower', 1386),
#  ('companies', 1381),
#  ('fbi', 1377),
#  ('video', 1377),
#  ('brave', 1370),
#  ('ag', 1368),
#  ('plans', 1366),
#  ('wants', 1364),
#  ('left', 1362),
#  ('impact', 1359),
#  ('ban', 1357),
#  ('then', 1356),
#  ('needed', 1350),
#  ('residents', 1345),
#  ('border', 1342),
#  ('things', 1339),
#  ('protections', 1337),
#  ('instead', 1334),
#  ('police', 1334),
#  ('student', 1332),
#  ('college', 1331),
#  ('fellow', 1328),
#  ('really', 1325),
#  ('thing', 1314),
#  ('called', 1312),
#  ('enforcement', 1309),
#  ('heard', 1308),
#  ('follow', 1306),
#  ('court', 1304),
#  ('affected', 1303),
#  ('investigation', 1302),
#  ('trillion', 1300),
#  ('industry', 1296),
#  ('votes', 1294),
#  ('tour', 1285),
#  ('already', 1284),
#  ('major', 1284),
#  ('russian', 1283),
#  ('once', 1276),
#  ('weekend', 1274),
#  ('wall', 1273),
#  ('citizens', 1271),
#  ('sessions', 1270),
#  ('democracy', 1269),
#  ('deficit', 1268),
#  ('others', 1264),
#  ('calls', 1263),
#  ('dream', 1263),
#  ('chair', 1262),
#  ('el', 1259),
#  ('florida', 1259),
#  ('foreign', 1258),
#  ('research', 1258),
#  ('each', 1257),
#  ('op', 1257),
#  ('shooting', 1257),
#  ('ways', 1257),
#  ('continues', 1251),
#  ('et', 1251),
#  ('dangerous', 1249),
#  ('folks', 1246),
#  ('defenddaca', 1245),
#  ('farmers', 1242),
#  ('hurt', 1240),
#  ('loved', 1240),
#  ('politics', 1239),
#  ('spending', 1239),
#  ('wages', 1239),
#  ('annual', 1235),
#  ('control', 1233),
#  ('general', 1233),
#  ('importance', 1233),
#  ('aid', 1232),
#  ('true', 1231),
#  ('grow', 1230),
#  ('minutes', 1229),
#  ('party', 1228),
#  ('face', 1226),
#  ('rules', 1224),
#  ('hosting', 1223),
#  ('thousands', 1220),
#  ('california', 1213),
#  ('constituents', 1213),
#  ('100', 1208),
#  ('old', 1206),
#  ('far', 1202),
#  ('group', 1197),
#  ('took', 1196),
#  ('consumers', 1195),
#  ('nytimes', 1194),
#  ('urge', 1194),
#  ('passing', 1189),
#  ('prevent', 1189),
#  ('1st', 1188),
#  ('gov', 1188),
#  ('reminder', 1188),
#  ('troops', 1187),
#  ('receive', 1180),
#  ('fact', 1177),
#  ('man', 1176),
#  ('nuclear', 1176),
#  ('giving', 1174),
#  ('area', 1169),
#  ('break', 1169),
#  ('joe', 1166),
#  ('quality', 1165),
#  ('facebook', 1164),
#  ('resolution', 1164),
#  ('en', 1161),
#  ('16', 1157),
#  ('key', 1155),
#  ('stevescalise', 1153),
#  ('speech', 1151),
#  ('shouldn', 1150),
#  ('threat', 1150),
#  ('thanksgiving', 1148),
#  ('served', 1147),
#  ('sanctions', 1143),
#  ('financial', 1140),
#  ('current', 1139),
#  ('legislative', 1135),
#  ('past', 1134),
#  ('utpol', 1134),
#  ('hours', 1131),
#  ('details', 1130),
#  ('behind', 1129),
#  ('record', 1124),
#  ('benefit', 1123),
#  ('serving', 1123),
#  ('vets', 1122),
#  ('taxpayers', 1121),
#  ('commitment', 1120),
#  ('veteran', 1116),
#  ('signed', 1112),
#  ('laws', 1110),
#  ('ending', 1109),
#  ('everything', 1109),
#  ('huge', 1104),
#  ('immigrants', 1102),
#  ('discussing', 1100),
#  ('drug', 1099),
#  ('director', 1098),
#  ('forget', 1095),
#  ('game', 1095),
#  ('came', 1093),
#  ('cfpb', 1093),
#  ('fcc', 1093),
#  ('abetterdeal', 1091),
#  ('lot', 1091),
#  ('heart', 1090),
#  ('opening', 1089),
#  ('breaks', 1088),
#  ('low', 1086),
#  ('leader', 1085),
#  ('praying', 1085),
#  ('pleased', 1084),
#  ('ones', 1079),
#  ('following', 1077),
#  ('combat', 1076),
#  ('excited', 1076),
#  ('due', 1070),
#  ('social', 1068),
#  ('50', 1067),
#  ('such', 1063),
#  ('donald', 1061),
#  ('message', 1060),
#  ('simple', 1058),
#  ('25', 1057),
#  ('corporate', 1056),
#  ('west', 1054),
#  ('asked', 1052),
#  ('ohio', 1051),
#  ('ask', 1050),
#  ('massive', 1048),
#  ('helps', 1046),
#  ('private', 1046),
#  ('virginia', 1042),
#  ('chance', 1040),
#  ('tx', 1037),
#  ('south', 1035),
#  ('send', 1034),
#  ('role', 1030),
#  ('civil', 1026),
#  ('policies', 1026),
#  ('attacks', 1023),
#  ('visiting', 1019),
#  ('proposal', 1018),
#  ('senjohnmccain', 1018),
#  ('award', 1017),
#  ('epidemic', 1017),
#  ('heroes', 1012),
#  ('list', 1012),
#  ('training', 1012),
#  ('celebrating', 1011),
#  ('oppose', 1011),
#  ('hurricaneirma', 1010),
#  ('13', 1009),
#  ('shows', 1009),
#  ('repdonbeyer', 1008),
#  ('schools', 1006),
#  ('mr', 1004),
#  ('washingtonpost', 1003),
#  ('senatemajldr', 1002),
#  ('fund', 999),
#  ('matter', 999),
#  ('set', 998),
#  ('broken', 995),
#  ('killed', 994),
#  ('progress', 993),
#  ('works', 991),
#  ('dollars', 990),
#  ('passes', 988),
#  ('possible', 988),
#  ('helped', 987),
#  ('science', 985),
#  ('harassment', 984),
#  ('interest', 984),
#  ('something', 984),
#  ('graham', 983),
#  ('online', 983),
#  ('sharing', 983),
#  ('interview', 982),
#  ('yes', 982),
#  ('promise', 981),
#  ('unacceptable', 980),
#  ('chief', 979),
#  ('housedemocrats', 978),
#  ('release', 978),
#  ('foxbusiness', 977),
#  ('accountable', 976),
#  ('didn', 976),
#  ('problem', 976),
#  ('available', 975),
#  ('sent', 972),
#  ('deadline', 971),
#  ('media', 971),
#  ('anniversary', 970),
#  ('protection', 970),
#  ('months', 969),
#  ('case', 965),
#  ('democratic', 965),
#  ('whitehouse', 965),
#  ('actions', 964),
#  ('ahead', 963),
#  ('build', 963),
#  ('conditions', 962),
#  ('trade', 961),
#  ('turn', 961),
#  ('assault', 959),
#  ('starting', 958),
#  ('held', 957),
#  ('demand', 956),
#  ('hill', 954),
#  ('st', 954),
#  ('seen', 952),
#  ('times', 951),
#  ('woman', 950),
#  ('40', 947),
#  ('savetps', 947),
#  ('keeping', 946),
#  ('leave', 946),
#  ('data', 944),
#  ('question', 944),
#  ('recent', 944),
#  ('close', 943),
#  ('urging', 942),
#  ('values', 942),
#  ('wishing', 942),
#  ('solutions', 939),
#  ('stories', 938),
#  ('politico', 937),
#  ('run', 937),
#  ('single', 937),
#  ('leading', 935),
#  ('vp', 935),
#  ('cancer', 933),
#  ('san', 933),
#  ('tech', 933),
#  ('paying', 931),
#  ('told', 931),
#  ('strengthen', 929),
#  ('caucus', 926),
#  ('pres', 925),
#  ('veteransday', 925),
#  ('amazing', 922),
#  ('wonderful', 922),
#  ('committed', 921),
#  ('defend', 920),
#  ('vital', 918),
#  ('partisan', 916),
#  ('majority', 915),
#  ('passage', 915),
#  ('mayor', 911),
#  ('post', 911),
#  ('market', 910),
#  ('friday', 908),
#  ('path', 908),
#  ('saturday', 907),
#  ('led', 906),
#  ('failed', 905),
#  ('housing', 905),
#  ('anyone', 904),
#  ('july', 903),
#  ('waysandmeansgop', 903),
#  ('god', 901),
#  ('sacrifice', 901),
#  ('historic', 899),
#  ('repalgreen', 899),
#  ('housejudiciary', 898),
#  ('repgoodlatte', 898),
#  ('serious', 894),
#  ('little', 892),
#  ('nancypelosi', 891),
#  ('corybooker', 889),
#  ('development', 889),
#  ('become', 886),
#  ('cutting', 886),
#  ('goptaxplan', 885),
#  ('carry', 884),
#  ('mueller', 883),
#  ('person', 881),
#  ('secure', 881),
#  ('used', 878),
#  ('words', 878),
#  ('afford', 877),
#  ('individual', 877),
#  ('800', 876),
#  ('opportunities', 876),
#  ('truth', 876),
#  ('department', 875),
#  ('remarks', 875),
#  ('thankful', 874),
#  ('moment', 872),
#  ('expand', 871),
#  ('un', 869),
#  ('common', 868),
#  ('interests', 868),
#  ('holding', 867),
#  ('least', 867),
#  ('living', 867),
#  ('level', 866),
#  ('neighbors', 865),
#  ('recipients', 865),
#  ('sense', 861),
#  ('earned', 859),
#  ('deliver', 858),
#  ('remain', 858),
#  ('tps', 858),
#  ('devastating', 856),
#  ('houston', 856),
#  ('gives', 855),
#  ('afternoon', 854),
#  ('black', 854),
#  ('mean', 854),
#  ('putin', 854),
#  ('impacted', 853),
#  ('hour', 852),
#  ('equifax', 849),
#  ('ca', 845),
#  ('smallbiz', 845),
#  ('innovation', 844),
#  ('started', 844),
#  ('rates', 843),
#  ('twitter', 843),
#  ('farm', 842),
#  ('worse', 842),
#  ('below', 841),
#  ('answer', 840),
#  ('moving', 840),
#  ('voter', 839),
#  ('agenda', 837),
#  ('ap', 837),
#  ('gopbudget', 836),
#  ('roslehtinen', 836),
#  ('sabotage', 836),
#  ('hurricaneharvey', 834),
#  ('israel', 834),
#  ('comes', 833),
#  ('growing', 833),
#  ('gets', 832),
#  ('kushner', 832),
#  ('rate', 832),
#  ('point', 828),
#  ('street', 828),
#  ('cbo', 827),
#  ('storm', 827),
#  ('status', 826),
#  ('along', 825),
#  ('evacuation', 825),
#  ('los', 824),
#  ('dreamactnow', 823),
#  ('appreciate', 821),
#  ('incredible', 820),
#  ('saying', 820),
#  ('17', 819),
#  ('al', 818),
#  ('reduce', 818),
#  ('terror', 818),
#  ('weeks', 818),
#  ('minute', 817),
#  ('solution', 817),
#  ('using', 817),
#  ('individuals', 814),
#  ...]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 

# 根据词袋模型分析结果绘制词云图
wc = WordCloud(
    width=1200, 
    height=800, 
    background_color='white', 
    font_path='D:\\平常用不到\\大三下学期\\媒体信息数据挖掘\\楚辰体(个人免费商用)_@字体视界\\字体安装文件\\楚辰体_@字体视界.ttf'
).generate_from_frequencies(word_freq)

# 显示词云图
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
plt.savefig('wordcloud_twi.png', dpi=100)
